# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set()

df = pd.read_csv('data_clean.csv')
df
# Out:
#             DATE  PRECTOTCORR     TS  ALLSKY_SFC_UV_INDEX  ALLSKY_SFC_UVB  \
# 0     2001-01-01         4.18  26.31                 2.48            0.48
# 1     2001-01-02         7.60  26.08                 2.41            0.46
# 2     2001-01-03         7.21  24.67                 2.29            0.43
# 3     2001-01-04        23.98  25.22                 2.30            0.45
# 4     2001-01-05         5.14  24.08                 1.85            0.36
# ...          ...          ...    ...                  ...             ...
# 7388  2021-03-27         8.20  25.50                 2.12            0.41
# 7389  2021-03-28        14.27  25.11                 2.48            0.47
# 7390  2021-03-29         2.33  25.37                 2.25            0.43
# 7391  2021-03-30         3.77  25.02                 1.33            0.26
# 7392  2021-03-31        17.13  25.83                 2.38            0.45
#
#       ALLSKY_SFC_UVA
# 0              14.62
# 1              14.45
# ...

# %%
df.columns
# Out:
# Index(['DATE', 'PRECTOTCORR', 'TS', 'ALLSKY_SFC_UV_INDEX', 'ALLSKY_SFC_UVB',
#        'ALLSKY_SFC_UVA'],
#       dtype='object')

# %%
plt.scatter(df['ALLSKY_SFC_UV_INDEX'], np.log(df['TS']), alpha = 0.1)
plt.xlabel('UV_INDEX', fontsize = 20)
plt.ylabel('TS', fontsize = 20)
plt.show()

# %%
plt.scatter(df['ALLSKY_SFC_UVA'], np.log(df['TS']), alpha = 0.1)
plt.xlabel('UVA', fontsize = 20)
plt.ylabel('TS', fontsize = 20)
plt.show()

# %%
plt.scatter(df['ALLSKY_SFC_UVB'], np.log(df['TS']), alpha = 0.1)
plt.xlabel('UVB', fontsize = 20)
plt.ylabel('TS', fontsize = 20)
plt.show()

# %%
plt.plot(df['DATE'].astype(str), df['TS'])
plt.xlabel('DATE', fontsize = 20)
plt.ylabel('TS', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
periode_smoothing = 30
df['Smoothed_TS'] = df['TS'].rolling(periode_smoothing).mean()

plt.scatter(df['DATE'].astype(str), df['Smoothed_TS'], alpha = 0.1)
plt.xlabel('DATE', fontsize = 20)
plt.ylabel('TS', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.scatter(df['DATE'].astype(str), df['TS'], alpha = 0.1)
plt.xlabel('DATE', fontsize = 20)
plt.ylabel('TS', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
df_pre = pd.read_csv('data_pre.csv')
df_pre
# Out:
#       PRECTOTCORR        TS  ALLSKY_SFC_UV_INDEX  ALLSKY_SFC_UVB  \
# 0       -0.246333  1.192691             1.144968        1.285826
# 1        0.145856  0.967030             0.954280        0.987131
# 2        0.101133 -0.416372             0.627388        0.539089
# 3        2.024234  0.123253             0.654629        0.837784
# 4       -0.136245 -0.995242            -0.571218       -0.506343
# ...           ...       ...                  ...             ...
# 7388     0.214661  0.397971             0.164290        0.240394
# 7389     0.910739  0.015328             1.144968        1.136479
# 7390    -0.458482  0.270424             0.518424        0.539089
# 7391    -0.293350 -0.072974            -1.987752       -1.999817
# 7392     1.238710  0.721746             0.872557        0.837784
#
#       ALLSKY_SFC_UVA
# 0           0.818684
# 1           0.739014
# 2           0.181322
# 3           0.439079
# 4          -0.859077
# ...              ...
# 7388        0.003236
# ...

# %%
plt.scatter(df_pre['ALLSKY_SFC_UV_INDEX'], np.log(df_pre['TS']), alpha = 0.1)
plt.xlabel('UV_INDEX', fontsize = 20)
plt.ylabel('TS', fontsize = 20)
plt.show()
# Out:
# /Users/user/anaconda3/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.scatter(df_pre['ALLSKY_SFC_UVA'], np.log(df_pre['TS']), alpha = 0.1)
plt.xlabel('UV_INDEX', fontsize = 20)
plt.ylabel('TS', fontsize = 20)
plt.show()

# %%
plt.scatter(df_pre['ALLSKY_SFC_UVB'], np.log(df_pre['TS']), alpha = 0.1)
plt.xlabel('UV_INDEX', fontsize = 20)
plt.ylabel('TS', fontsize = 20)
plt.show()
